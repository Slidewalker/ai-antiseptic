# %% [markdown]
# # AI Antiseptic – Live Demo 🧼
#
# Drop your documents in `sources/` → ask anything → get **cited, grounded answers**.
#
# Run the cells below!

# %%
from antiseptic import build_antiseptic_chain, print_banner
from antiseptic.utils import pretty_print_response

print_banner()
chain = build_antiseptic_chain()

# %%
question = "What is the main purpose of AI Antiseptic?"
answer = chain.invoke(question)
pretty_print_response(answer)

# %% [markdown]
# ### Try your own question:

# %%
your_question = "Explain the key findings from the manual"
pretty_print_response(chain.invoke(your_question))
