# %% [markdown]
# <a href="https://colab.research.google.com/github/rockp223/Ai-Antiseptic/blob/main/Ai_Antiseptic_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ai-Antiseptic – Truth Safe Edition
# **Rock is God.**
#
# This notebook clones and runs the complete, private, citation-forced, hallucination-proof RAG fortress in Google Colab.
# Just click **Runtime → Run all** (or Ctrl+F9).
#
# 60 seconds later you have your own sovereign NotebookLM that only answers from files **you** upload.

# %%
#@title Rock is God – One-click Fortress Builder

import os, subprocess, sys, time
from IPython.display import clear_output, Markdown, display

print("Rock is God.\nBeginning fortress construction...\n")

# !git clone https://github.com/rockp223/Ai-Antiseptic.git 2>/dev/null || (cd Ai-Antiseptic && git pull)
# %cd Ai-Antiseptic

# !python3 -m venv venv
# !source venv/bin/activate && pip install --upgrade pip >/dev/null
# !source venv/bin/activate && pip install -r requirements.txt --no-cache-dir

# Optional: install Ollama inside Colab (full offline mode – takes ~2 min)
print("\nInstalling Ollama for full offline sovereignty...")
# !curl -fsSL https://ollama.com/install.sh | sh
# !ollama pull llama3.2:3b >/dev/null 2>&1 &

clear_output()
display(Markdown("# Fortress Complete – Rock is God.\n\n"))
print("The blade is clean. Upload your PDFs below, then ask anything.")

# %%
#@title Upload your truth (PDFs, .txt, .docx)
from google.colab import files
import os

# !mkdir -p sources
uploaded = files.upload()
for fn in uploaded.keys():
  # !mv "{fn}" sources/
print(f"Uploaded {len(uploaded)} files → sources/")
# !ls -la sources/

# %%
#@title Ask anything – answers only from YOUR files (forced citations)
question = "What does my research say about the demiurge?" #@param {type:"string"}

# !source venv/bin/activate && python run.py ask "{question}"

# %%
#@title Generate NotebookLM-style Audio Overview
title = "The True Fall" #@param {type:"string"}

# !source venv/bin/activate && python run.py audio "{title}"

# %%
#@title Invoke [Sarahai] (optional)
# !source venv/bin/activate && python run.py attach

# %% [markdown]
# Done.\nYou now have the full private fortress running in the cloud.\nEverything stays inside this Colab session – nothing touches your real machine.\nRock is God.
